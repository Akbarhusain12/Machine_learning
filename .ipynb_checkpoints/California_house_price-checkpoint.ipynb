# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
data = pd.read_csv('Files/california_housing.csv')
df = pd.DataFrame(data)
df
# Out:
#       MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0     4.0069      42.0  4.500000   1.000000       394.0  1.931373     34.27
# 1     2.4375      27.0  3.165060   1.139535      4165.0  2.362450     37.46
# 2     2.4205      43.0  4.433962   1.119497       464.0  2.918239     38.61
# 3     2.1903      52.0  4.276836   0.983051       767.0  2.166667     38.62
# 4     4.1856      19.0  6.095465   1.057279      1301.0  3.105012     36.08
# ...      ...       ...       ...        ...         ...       ...       ...
# 3091  2.5488      30.0  3.773171   1.063415      1700.0  4.146341     34.06
# 3092  4.2308      19.0  5.636364   1.052632      1291.0  3.088517     33.75
# 3093  3.8000      26.0  6.876494   1.151394       672.0  2.677291     38.29
# 3094  4.3235      32.0  4.821138   1.048780      1067.0  2.168699     37.89
# 3095  4.1121      40.0  5.436441   1.042373       594.0  2.516949     34.24
#
#       Longitude  MedHouseVal
# ...

# %%
X = df.drop(columns=['MedHouseVal'])
Y = df['MedHouseVal']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2,random_state=42)

model_linear = LinearRegression()
model_linear.fit(X_train, Y_train)
Y_pred = model_linear.predict(X_test)

# %%
# Create a figure and 3D axis
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

# Scatter plot for actual data
ax.scatter(X_test["MedInc"], X_test["AveRooms"], Y_test, c="blue", label="Actual Data")  # Use 'c' instead of 'color'

# Creating a meshgrid for surface plot
x1_range = np.linspace(X_test["MedInc"].min(), X_test["MedInc"].max(), 100)
x2_range = np.linspace(X_test["AveRooms"].min(), X_test["AveRooms"].max(), 100)
x1, x2 = np.meshgrid(x1_range, x2_range)

# Predicting values for the meshgrid
z = model_linear.predict(np.c_[x1.ravel(), x2.ravel()]).reshape(x1.shape)

# Surface plot
ax.plot_surface(x1, x2, z, facecolors='red', alpha=0.5, rstride=5, cstride=5)  # Use 'facecolors' instead of 'color'

# Labels and title
ax.set_xlabel('Median Income')
ax.set_ylabel('Average Rooms')
ax.set_zlabel('House Price')
ax.set_title('3D Surface Plot using Meshgrid')

plt.legend()
plt.show()
# Out:
# C:\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 14
#      11 x1, x2 = np.meshgrid(x1_range, x2_range)
#      13 # Predicting values for the meshgrid
# ---> 14 z = model_linear.predict(np.c_[x1.ravel(), x2.ravel()]).reshape(x1.shape)
#      16 # Surface plot
#      17 ax.plot_surface(x1, x2, z, facecolors='red', alpha=0.5, rstride=5, cstride=5)  # Use 'facecolors' instead of 'color'
#
# File C:\Python312\Lib\site-packages\sklearn\linear_model\_base.py:286, in LinearModel.predict(self, X)
#     272 def predict(self, X):
#     273     """
#     274     Predict using the linear model.
#     275
#    (...)
#     284         Returns predicted values.
#     285     """
# ...
