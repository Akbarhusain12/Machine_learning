# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = [10,20,30,40,50]
y = [20,25,35,55,45]

plt.plot(x,y)
plt.title("Plotting")
plt.show()

# %%
x = [10,20,30,40,50]
y = [20,25,35,55,45]

sns.lineplot(x=x,y=y)
plt.title("Plotting")
plt.show()
