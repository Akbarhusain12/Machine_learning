# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import warnings 
warnings.filterwarnings('ignore')

# %%
x = [10,20,30,40,50]
y = [20,25,35,55,45]

plt.plot(x,y)
plt.title("Plotting")
plt.show()

# %%
x = [10,20,30,40,50]
y = [20,25,35,55,45]

sns.lineplot(x=x,y=y)
plt.title("Plotting")
plt.show()

# %%
data = pd.read_csv("Files/house_prices.csv")

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#    House Size  House Price
# 0        1500       350000
# 1        1800       400000
# 2        2000       450000
# 3        2200       475000
# 4        2500       525000

# %%
x = df['House Size']
y = df['House Price']

# %%
plt.scatter(x,y)
plt.show()

# %%
labels = df['House Price'].value_counts().index  
plt.pie(y, labels=labels)  
plt.title("House Price Distribution")
plt.show()

# %%
plt.scatter(x,y)
plt.show()

# %%
plt.hist(x)
plt.show()

# %%
data = np.random.rand(5, 5)  
df = pd.DataFrame(data, columns=['A', 'B', 'C', 'D', 'E'])

corr = df.corr()
corr
# Out:
#           A         B         C         D         E
# A  1.000000 -0.278352  0.383686 -0.197728  0.646865
# B -0.278352  1.000000 -0.695644  0.221575 -0.309980
# C  0.383686 -0.695644  1.000000 -0.097282 -0.146451
# D -0.197728  0.221575 -0.097282  1.000000  0.042711
# E  0.646865 -0.309980 -0.146451  0.042711  1.000000

# %%
sns.heatmap(corr, annot=True, cmap="viridis", linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()

# %%
df = pd.DataFrame({'Category': ['A', 'B', 'A', 'C', 'B', 'A', 'C', 'C', 'B', 'A']})

sns.countplot(x=df['Category'], palette="viridis")
plt.title("Category Countplot")
plt.show()

# %%
df = pd.DataFrame({
    'Category': ['A', 'A', 'A', 'B', 'B', 'B', 'C', 'C', 'C'],
    'Values': [10, 20, 15, 25, 30, 22, 35, 40, 38]
})

sns.boxplot(x=df['Category'], y=df['Values'], palette="Set2")
plt.title("Boxplot Example")
plt.show()
